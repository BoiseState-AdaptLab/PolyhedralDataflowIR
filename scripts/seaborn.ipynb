# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

df = sns.load_dataset('iris')
sns.set_style("whitegrid")
 
# Without regression fit:
sns.regplot(x=df["sepal_length"], y=df["sepal_width"], fit_reg=True)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %matplotlib inline

df = pd.read_csv('/home/edavis/Work/VarDevEddie/scripts/data/poster_data.csv') #sns.load_dataset('iris')
sns.set_style("whitegrid")
 
plt.figure(figsize=(12, 12))
#ax = sns.lineplot(x=df["nThreads"], y=df["Speedup"], hue=df["Tensor"], style=df["Tensor"], legend='full', markers=True, dashes=False)
ax = sns.lineplot(x=df["nThreads"], y=df["Speedup"], hue=df["Format"], legend='full', markers=True, dashes=False, marker='s')
#ax.set_xscale('log')
#ax.set_yscale('log')
nthreads = df['nThreads'].unique()
xlabels = [str(t) for t in nthreads]
#ax.set(xticks=nthreads)
ax.xaxis.set_ticks(nthreads) #set the ticks to be a
ax.xaxis.set_ticklabels(xlabels) # change the ticks' names to x
ax

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %matplotlib inline

df = pd.read_csv('/home/edavis/Work/proto/data/euler_py.csv')
sns.set_style("whitegrid")

nthreads = df['nthreads'].unique()
threadstr = [str(nthread) for nthread in nthreads]
fuse_types = df['fuse_type'].unique()
xcol = 'nthreads'
ycol = 'speedup'
gcol = 'fuse_type'

plt.figure(figsize=(12, 12))
#ax = sns.lineplot(x=df["nThreads"], y=df["Speedup"], hue=df["Tensor"], style=df["Tensor"], legend='full', markers=True, dashes=False)
ax = sns.barplot(x=xcol, y=ycol, hue=gcol, data=df) #, legend='full', markers=True, dashes=False, marker='s')
#ax.set_xscale('log')
#ax.set_yscale('log')
ax.xaxis.set_ticks(nthreads) #set the ticks to be a
ax.xaxis.set_ticklabels(threadstr) # change the ticks' names to x
ax
